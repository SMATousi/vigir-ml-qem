# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Replace with your actual API token
api_token = ""

# Save the account permanently (by default in ~/.qiskit/qiskit-ibm.json)
QiskitRuntimeService.save_account(
    token=api_token,
    overwrite=True  # Overwrites existing saved credentials if any
    # channel="ibm_quantum"
)

# Load the account for use
service = QiskitRuntimeService()
# Out:
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-07-31 13:14:33,019: Default instance not set. Searching all available instances.
