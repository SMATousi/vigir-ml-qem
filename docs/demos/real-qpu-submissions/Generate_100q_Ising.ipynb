# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import random_clifford
from tqdm import tqdm

def generate_ising_twirl_circuits(num_qubits: int,
                                  num_circuits: int,
                                  depth: int = 10) -> list[QuantumCircuit]:
    """
    Generate a list of random 100-qubit Ising-twirl circuits.

    Parameters:
    - num_qubits: Number of qubits per circuit.
    - num_circuits: Total number of circuits to generate.
    - depth: Number of Trotter layers per circuit (default: 10).

    Returns:
    - circuits: List of QuantumCircuit objects.
    """
    circuits = []
    for idx in tqdm(range(num_circuits)):
        qc = QuantumCircuit(num_qubits)
        # Initial random single-qubit Clifford twirl
        for q in range(num_qubits):
            qc.append(random_clifford(1).to_instruction(), [q])
        # Ising Trotter layers with twirling
        for _layer in range(depth):
            # Random pairing (matching) of qubits for ZZ interactions
            perm = np.random.permutation(num_qubits)
            for i in range(0, num_qubits - 1, 2):
                q1, q2 = perm[i], perm[i + 1]
                qc.rzz(np.pi / 4, q1, q2)
            # Twirl between layers with single-qubit Cliffords
            for q in range(num_qubits):
                qc.append(random_clifford(1).to_instruction(), [q])
        circuits.append(qc)
    return circuits

# %%
num_qubits = 100
num_circuits = 10
depth = 10  # adjust as needed
circuits = generate_ising_twirl_circuits(num_qubits, num_circuits, depth)
print(f"Generated {len(circuits)} Ising-twirl circuits with {num_qubits} qubits and depth {depth}")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:02<00:00,  3.85it/s]
# Generated 10 Ising-twirl circuits with 100 qubits and depth 10

# %%
circuits[0].draw()
# Out:
#       ┌──────────────────────────────────────────────────────┐          »
#  q_0: ┤ Clifford: Stabilizer = ['-Z'], Destabilizer = ['+X'] ├──────────»
#       ├──────────────────────────────────────────────────────┤          »
#  q_1: ┤ Clifford: Stabilizer = ['+X'], Destabilizer = ['-Z'] ├──────────»
#       ├──────────────────────────────────────────────────────┤          »
#  q_2: ┤ Clifford: Stabilizer = ['-Y'], Destabilizer = ['-Z'] ├──────────»
#       ├──────────────────────────────────────────────────────┤          »
#  q_3: ┤ Clifford: Stabilizer = ['+Y'], Destabilizer = ['-Z'] ├──────────»
#       ├──────────────────────────────────────────────────────┤          »
#  q_4: ┤ Clifford: Stabilizer = ['-Y'], Destabilizer = ['-Z'] ├──────────»
#       ├──────────────────────────────────────────────────────┤          »
#  q_5: ┤ Clifford: Stabilizer = ['-Z'], Destabilizer = ['+X'] ├──────────»
#       ├──────────────────────────────────────────────────────┤          »
# ...

# %%
import numpy as np
import json
from qiskit import transpile
from qiskit_ibm_runtime import QiskitRuntimeService, Session
from qiskit_aer.primitives import Estimator as AerEstimator
from qiskit.quantum_info import SparsePauliOp
from mitiq import zne
from mitiq.zne.scaling.folding import fold_gates_at_random
from mitiq.zne import execute_with_zne
from mitiq.zne.scaling import fold_gates_at_random
from mitiq.zne.inference import RichardsonFactory
from qiskit_ibm_runtime import QiskitRuntimeService, Session, Estimator as RuntimeEstimator
from qiskit.quantum_info import SparsePauliOp
from mitiq.zne import execute_with_zne
from mitiq.zne.scaling import fold_gates_at_random
from mitiq.zne.inference import RichardsonFactory

def build_observables(num_qubits, measure_qubits):
    """Create Z Pauli observables on given qubits."""
    obs = []
    for q in measure_qubits:
        label = ['I'] * num_qubits
        label[q] = 'Z'
        obs.append(SparsePauliOp(''.join(label)))
    return obs

def run_zne_on_backend(circuits, backend_name, measure_qubits,
                       scale_factors, shots=8192):
    """
    Returns a dict mapping each circuit index to:
      {'noisy': [...], 'mitigated': [...]}
    """
    # 1. Get service and backend
    service = QiskitRuntimeService()                      # V2 primitives :contentReference[oaicite:7]{index=7}
    backend = service.backend(backend_name)
    circuits = transpile(circuits, backend=backend)

    # 2. Open a session
    with Session(backend) as session:
        estimator = RuntimeEstimator(session)             # pass Session as mode :contentReference[oaicite:8]{index=8}

        # 3. Set your shot count via options.default_shots
        estimator.options.default_shots = shots           # control shots here :contentReference[oaicite:9]{index=9}

        observables = build_observables(
            circuits[0].num_qubits, measure_qubits
        )
        results = {}

        # 4. Loop over circuits & observables
        for idx, circ in enumerate(circuits):
            noisy_vals = []
            mitigated_vals = []

            for obs in observables:
                # Raw (noisy) expectation
                job = estimator.run([(circ, obs)])           # uses default_shots :contentReference[oaicite:10]{index=10}
                raw = job.result().values[0]
                noisy_vals.append(raw)

                # ZNE-mitigated expectation
                fn = lambda c: estimator.run([c], [obs]) \
                                   .result().values[0]
                zne_val = execute_with_zne(
                    circuit=circ,
                    executor=fn,
                    scale_factors=scale_factors,
                    noise_scaling=fold_gates_at_random,
                    extrapolation_factory=RichardsonFactory()
                )
                mitigated_vals.append(zne_val)

            results[idx] = {
                'noisy': noisy_vals,
                'mitigated': mitigated_vals
            }

    return results

# %%
from typing import Optional
from qiskit.quantum_info import SparsePauliOp
from mitiq.zne.scaling import fold_gates_at_random
from typing import Callable
from qiskit.quantum_info import SparsePauliOp
from mitiq.zne.scaling import fold_gates_at_random

def _first_ev(job_result) -> float:
    pub = job_result[0]         # PubResult
    evs = pub.data.evs          # usually a 1-element array/list
    return float(evs)

def make_executor_for(obs: SparsePauliOp) -> Callable:
    # Returns a float-like executor with the observable "baked in"
    def exec_obs(circ) -> float:
        job = estimator.run([(circ, obs)])
        return _first_ev(job.result())
    return exec_obs



# circuits = generate_ising_twirl_circuits(100, 500, depth=10)
backend_name = "ibm_kingston"
measure_qubits = list(range(5))
scale_factors = [1.0, 2.0, 3.0]
shots=8000
factory = RichardsonFactory(scale_factors)
"""
Returns a dict mapping each circuit index to:
  {'noisy': [...], 'mitigated': [...]}
"""
# 1. Get service and backend
service = QiskitRuntimeService()                      # V2 primitives :contentReference[oaicite:7]{index=7}
backend = service.backend(backend_name)
circuits = transpile(circuits, backend=backend)

# 2. Open a session
with Session(backend) as session:
    estimator = RuntimeEstimator(session)
    estimator.options.default_shots = shots

    observables = build_observables(
        circuits[0].num_qubits, measure_qubits
    )
    results = {}

    # --- define a type-hinted executor for Mitiq ---
    def qiskit_executor(circ, observable: Optional[SparsePauliOp] = None, **kwargs) -> float:
        # Mitiq will pass `observable` here when you call execute_with_zne(..., observable=obs, ...)
        job = estimator.run([(circ, observable)])
        res = job.result()          # PrimitiveResult[PubResult]
        return res.values[0]        # a float expectation value

    for idx, circ in enumerate(circuits):
        noisy_vals = []
        mitigated_vals = []
    
        for obs in observables:
            # 1) Raw expectation (no ZNE)
            job = estimator.run([(circ, obs)])
            raw = _first_ev(job.result())
            noisy_vals.append(raw)
    
            # 2) ZNE expectation:
            #    Use a float-returning executor with the observable captured,
            #    and DO NOT pass 'observable=' to execute_with_zne.
            exec_for_obs = make_executor_for(obs)
            zne_val = execute_with_zne(
                circ,
                exec_for_obs,                 # float-like executor
                factory=factory,
                scale_noise=fold_gates_at_random,
            )
            mitigated_vals.append(zne_val)
    
        results[idx] = {'noisy': noisy_vals, 'mitigated': mitigated_vals}
        print(f"Done with circuit number: {idx}")


# Save results
with open("zne_5qubit_results.json", "w") as f:
    json.dump(results, f, indent=2)

print(f"Saved noisy and mitigated results for {len(results)} circuits")
# Out:
# ---------------------------------------------------------------------------
# IBMInputValueError                        Traceback (most recent call last)
# Cell In[22], line 68
#      64     # 2) ZNE expectation:
#      65     #    Use a float-returning executor with the observable captured,
#      66     #    and DO NOT pass 'observable=' to execute_with_zne.
#      67     exec_for_obs = make_executor_for(obs)
# ---> 68     zne_val = execute_with_zne(
#      69         circ,
#      70         exec_for_obs,                 # float-like executor
#      71         factory=factory,
#      72         scale_noise=fold_gates_at_random,
#      73     )
#      74     mitigated_vals.append(zne_val)
#      76 results[idx] = {'noisy': noisy_vals, 'mitigated': mitigated_vals}
#
# File ~/miniconda3/envs/zne-qem/lib/python3.11/site-packages/mitiq/zne/zne.py:112, in execute_with_zne(circuit, executor, observable, factory, scale_noise, num_to_average)
#     109 if num_to_average < 1:
# ...

# %%
float(val)
# Out:
# 0.9921098421019785

# %%
factory = RichardsonFactory(scale_factors)

# %%
# from mitiq import execute_with_zne
# from mitiq.zne.scaling import fold_gates_at_random

mitigated = execute_with_zne(
    circ,                  # your QuantumCircuit
    fn,              # callable(circ) → float
    observable=obs,           # e.g. a SparsePauliOp
    factory=factory,          # pass the factory you built
    scale_noise=fold_gates_at_random
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 # from mitiq import execute_with_zne
#       2 # from mitiq.zne.scaling import fold_gates_at_random
# ----> 4 mitigated = execute_with_zne(
#       5     circ,                  # your QuantumCircuit
#       6     fn,              # callable(circ) → float
#       7     observable=obs,           # e.g. a SparsePauliOp
#       8     factory=factory,          # pass the factory you built
#       9     scale_noise=fold_gates_at_random
#      10 )
#
# File ~/miniconda3/envs/zne-qem/lib/python3.11/site-packages/mitiq/zne/zne.py:112, in execute_with_zne(circuit, executor, observable, factory, scale_noise, num_to_average)
#     109 if num_to_average < 1:
#     110     raise ValueError("Argument `num_to_average` must be a positive int.")
# --> 112 return factory.run(
# ...
